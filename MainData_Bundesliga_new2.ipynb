# %%
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup as soup
from urllib.request import urlopen as uReq
import urllib.request

# %%
Bundesliga_assists_url = "https://www.foxsports.com/soccer/stats?competition=4&season=20180&category=STANDARD&pos=0&team=0&isOpp=0&sort=4&sortOrder=0&page=2"

# %%
uClient = uReq(Bundesliga_assists_url)
Bundesliga_assists_url_page_html = uClient.read()
uClient.close()

# %%
Bundesliga_assists_page_soup = soup(Bundesliga_assists_url_page_html,"html.parser")

# %%
assist_Bundesliga_playerName = Bundesliga_assists_page_soup.findAll("a",{"class":"wisbb_fullPlayer"})
print(assist_Bundesliga_playerName[0].span.text)
#a,b = assist_Bundesliga_playerName[14].span.text.split(',')
# Out:
# Richter, Marco

# %%
assist_Bundesliga_Name = []
for i in range(50):
    get_assist_playerName = assist_Bundesliga_playerName[i].span.text.split(', ')
    #print(T_get_assist_playerName)
    #a,b = T_get_assist_playerName.split(',')
    #if len(b) == 0
    if len(get_assist_playerName) == 2:
        a = get_assist_playerName[1]
        b = get_assist_playerName[0]
        c = a+' '+b
    else:
        b = get_assist_playerName[0]
        a = ''
        c = b
    assist_Bundesliga_Name.append(c)
    
print(assist_Bundesliga_Name)
# Out:
# ['Marco Richter', 'Serge Gnabry', 'Nico Schulz', 'Ludwig Augustinsson', 'Christian Pulisic', 'Janik Haberer', 'Charles Aranguiz', 'Franck Ribery', 'James Rodriguez', 'Bastian Oczipka', 'Matthias Zimmermann', 'Josip Brekalo', 'Admir Mehmedi', 'Leonardo Bittencourt', 'Andre Hahn', 'Jean Zimmer', 'Alassane Plea', 'Davy Klaassen', 'Jerome Roussillon', 'Javairo Dilrosun', 'Nicolas Gonzalez', 'Dodi Lukebakio', 'Aaron Martin', 'Jean-Paul Boetius', 'Niko Giesselmann', 'Patrick Herrmann', 'Miiko Albornoz', 'Alexander Hack', 'Danny Latza', 'Eduard Lowen', 'Enrico Valentini', 'Jeffrey Gouweleeuw', 'Philipp Max', 'Florian Grillitsch', 'Andrej Kramaric', 'Adam Szalai', 'Steven Zuber', 'Diego Demme', 'Yussuf Poulsen', 'Marcel Sabitzer', 'Ondrej Duda', 'Vedad Ibisevic', 'Salomon Kalou', 'Marvin Plattenhardt', 'Jordan Torunarigha', 'Mitchell Weiser', 'Ishak Belfodil', 'Thomas Delaney', 'Theo Gebre Selassie', 'Jerome Gondorf']

# %%
Bundesliga_assistsPlusGoal_made = Bundesliga_assists_page_soup.findAll('tr',{"class":"wisbb_fvStand"})
print(Bundesliga_assistsPlusGoal_made[1].contents[9].text)
# Out:
# 0

# %%
Bundesliga_assistsPlusGoal_made_list = []
for i in range(1,51):
    Bundesliga_assists = Bundesliga_assistsPlusGoal_made[i].contents[9].text
    Bundesliga_assistsPlusGoal_made_list.append(Bundesliga_assists)
    
print(Bundesliga_assistsPlusGoal_made_list)
# Out:
# ['0', '7', '1', '1', '2', '1', '1', '4', '7', '1', '1', '2', '6', '1', '2', '1', '11', '3', '2', '2', '2', '8', '0', '1', '0', '3', '1', '1', '0', '2', '0', '0', '2', '0', '14', '4', '5', '0', '15', '3', '10', '9', '5', '0', '2', '1', '10', '2', '2', '2']

# %%
Bundesliga_assists_made = Bundesliga_assists_page_soup.findAll('td',{"class":"wisbb_priorityColumn wisbb_selected"})
print(len(Bundesliga_assists_made))
# Out:
# 50

# %%
Bundesliga_assists_made_list = []
for i in range(50):
    Bundesliga_assists = Bundesliga_assists_made[i].text
    Bundesliga_assists_made_list.append(Bundesliga_assists)
    
print(Bundesliga_assists_made_list)
# Out:
# ['3', '3', '3', '3', '3', '3', '3', '3', '3', '3', '3', '3', '3', '3', '3', '3', '3', '3', '3', '3', '3', '3', '3', '3', '3', '2', '2', '2', '2', '2', '2', '2', '2', '2', '2', '2', '2', '2', '2', '2', '2', '2', '2', '2', '2', '2', '2', '2', '2', '2']

# %%
Bundesliga_assist_club = Bundesliga_assists_page_soup.findAll('span',{"class":"wisbb_tableAbbrevLink"})
print(Bundesliga_assist_club[8].text)
print(Bundesliga_assist_club[1].text)
print("asd")
# Out:
#  MUN
#
#  MUN
#
# asd

# %%
Bundesliga_assist_club_list =[]
for i in range(50):
    get_club_name = Bundesliga_assist_club[i].text
    #print( get_club_name)
    get_club_name = get_club_name[1:4]
    Bundesliga_assist_club_list.append(get_club_name)
    
    #Bundesliga_assist_club_list.append(get_club_prefix)
    
print(Bundesliga_assist_club_list)
# Out:
# ['AUG', 'MUN', 'HOF', 'BRE', 'DOR', 'FBG', 'LEV', 'MUN', 'MUN', 'SKE', 'DUS', 'WOL', 'WOL', 'HOF', 'AUG', 'DUS', 'BM\n', 'BRE', 'WOL', 'HB\n', 'SGT', 'DUS', 'MAI', 'MAI', 'DUS', 'BM\n', 'HAN', 'MAI', 'MAI', 'FCN', 'FCN', 'AUG', 'AUG', 'HOF', 'HOF', 'HOF', 'SGT', 'RBL', 'RBL', 'RBL', 'HB\n', 'HB\n', 'HB\n', 'HB\n', 'HB\n', 'LEV', 'HOF', 'DOR', 'BRE', 'FBG']

# %%
PlayerID_Bundesliga_assist_list = []
for i in range(50):
    make_id = assist_Bundesliga_Name[i][0:4] + Bundesliga_assist_club_list[i]
    PlayerID_Bundesliga_assist_list.append(make_id)
    
print(PlayerID_Bundesliga_assist_list)
# Out:
# ['MarcAUG', 'SergMUN', 'NicoHOF', 'LudwBRE', 'ChriDOR', 'JaniFBG', 'CharLEV', 'FranMUN', 'JameMUN', 'BastSKE', 'MattDUS', 'JosiWOL', 'AdmiWOL', 'LeonHOF', 'AndrAUG', 'JeanDUS', 'AlasBM\n', 'DavyBRE', 'JeroWOL', 'JavaHB\n', 'NicoSGT', 'DodiDUS', 'AaroMAI', 'JeanMAI', 'NikoDUS', 'PatrBM\n', 'MiikHAN', 'AlexMAI', 'DannMAI', 'EduaFCN', 'EnriFCN', 'JeffAUG', 'PhilAUG', 'FlorHOF', 'AndrHOF', 'AdamHOF', 'StevSGT', 'DiegRBL', 'YussRBL', 'MarcRBL', 'OndrHB\n', 'VedaHB\n', 'SaloHB\n', 'MarvHB\n', 'JordHB\n', 'MitcLEV', 'IshaHOF', 'ThomDOR', 'TheoBRE', 'JeroFBG']

# %%
Bundesliga_assist_data = list(zip(assist_Bundesliga_Name,Bundesliga_assist_club_list,Bundesliga_assists_made_list,PlayerID_Bundesliga_assist_list))
Bundesliga_assist_df = pd.DataFrame(data = Bundesliga_assist_data,columns = ['Player Name','Club','Assists','PlayerID'])
Bundesliga_assist_df.head()
# Out:
#            Player Name Club Assists PlayerID
# 0        Marco Richter  AUG       3  MarcAUG
# 1         Serge Gnabry  MUN       3  SergMUN
# 2          Nico Schulz  HOF       3  NicoHOF
# 3  Ludwig Augustinsson  BRE       3  LudwBRE
# 4    Christian Pulisic  DOR       3  ChriDOR

# %%
Bundesliga_assist_df['Goals'] = Bundesliga_assistsPlusGoal_made_list

# %%
Bundesliga_assist_df
# Out:
#              Player Name  Club Assists  PlayerID Goals
# 0          Marco Richter   AUG       3   MarcAUG     0
# 1           Serge Gnabry   MUN       3   SergMUN     7
# 2            Nico Schulz   HOF       3   NicoHOF     1
# 3    Ludwig Augustinsson   BRE       3   LudwBRE     1
# 4      Christian Pulisic   DOR       3   ChriDOR     2
# 5          Janik Haberer   FBG       3   JaniFBG     1
# 6       Charles Aranguiz   LEV       3   CharLEV     1
# 7          Franck Ribery   MUN       3   FranMUN     4
# 8        James Rodriguez   MUN       3   JameMUN     7
# 9        Bastian Oczipka   SKE       3   BastSKE     1
# 10   Matthias Zimmermann   DUS       3   MattDUS     1
# 11         Josip Brekalo   WOL       3   JosiWOL     2
# 12         Admir Mehmedi   WOL       3   AdmiWOL     6
# 13  Leonardo Bittencourt   HOF       3   LeonHOF     1
# 14            Andre Hahn   AUG       3   AndrAUG     2
# 15           Jean Zimmer   DUS       3   JeanDUS     1
# ...

# %%
Fox_goal_URL = 'https://www.foxsports.com/soccer/stats?competition=4&season=20180&category=STANDARD&pos=0&team=0&isOpp=0&sort=3&sortOrder=0&page=2'

# %%
uClient = uReq(Fox_goal_URL)
page_html = uClient.read()
uClient.close()

# %%
Fox_goal_page_soup = soup(page_html,"html.parser")

# %%
Fox_goal_Name_Bundesliga = Fox_goal_page_soup.findAll('a',{"class":"wisbb_fullPlayer"})
print(len(Fox_goal_Name_Bundesliga))
# Out:
# 50

# %%
Fox_goal_name = []
for i in range(50):
    get_Goal_playerName_Fox = Fox_goal_Name_Bundesliga[i].span.text.split(', ')
    #print(T_get_assist_playerName)
    #a,b = T_get_assist_playerName.split(',')
    #if len(b) == 0
    if len(get_Goal_playerName_Fox) == 2:
        a =get_Goal_playerName_Fox[1]
        b = get_Goal_playerName_Fox[0]
        c = a+' '+b
    else:
        b = get_Goal_playerName_Fox[0]
        a = ''
        c = b
    Fox_goal_name.append(c)

print(Fox_goal_name)
# Out:
# ['Mario Gotze', 'Lucas Holer', 'Florian Niederlechner', 'Julian Brandt', 'Franck Ribery', 'Daniel Caligiuri', 'Breel Embolo', 'Nicolai Muller', 'Ji Dong Won', 'Mikael Ishak', 'Hanno Behrens', 'Kaan Ayhan', 'Hendrik Weydandt', 'Patrick Herrmann', 'Lars Stindl', 'Denis Zakaria', 'Ihlas Bebou', 'Michael Gregoritsch', 'Martin Hinteregger', 'Rani Khedira', 'Jonathan Schmid', 'Jean-Kevin Augustin', 'Lukas Klostermann', 'Marcel Sabitzer', 'Davie Selke', 'Johannes Eggestein', 'Lucas Alario', 'Kingsley Coman', 'Arjen Robben', 'Nabil Bentaleb', 'Anastasios Donis', 'Renato Steffen', 'Steven Skrzybski', 'Bobby Wood', 'Yuya Osako', 'Davy Klaassen', 'Claudio Pizarro', 'Marko Grujic', 'Axel Witsel', 'Sergio Cordova', 'Nico Elvedi', 'Christoph Kramer', 'Felipe', 'Niclas Fullkrug', 'Jonathas', 'Daniel Brosinski', 'Jean-Philippe Gbamin', 'Anthony Ujah', 'Eduard Lowen', 'Georg Margreitter']

# %%
Fox_club_name = Fox_goal_page_soup.findAll('td',{"class":"wisbb_priorityColumn wisbb_selected"})
Fox_club_name[0].text
# Out:
# '4'

# %%
Fox_GoalScored_Bundesliga =[]
for i in range(50):
    get_goals = Fox_club_name[i].text
    Fox_GoalScored_Bundesliga.append(get_goals)
    

print(Fox_GoalScored_Bundesliga)
# Out:
# ['4', '4', '4', '4', '4', '4', '4', '4', '4', '4', '4', '4', '4', '3', '3', '3', '3', '3', '3', '3', '3', '3', '3', '3', '3', '3', '3', '3', '3', '3', '3', '3', '3', '3', '3', '3', '3', '3', '3', '3', '2', '2', '2', '2', '2', '2', '2', '2', '2', '2']

# %%
Fox_GoalScoredPlusAssist_Bundesliga = Fox_goal_page_soup.findAll('tr',{"class":"wisbb_fvStand"})
print(Fox_GoalScoredPlusAssist_Bundesliga[0].contents[11].text)
# Out:
# A

# %%
Fox_GoalScoredPlusAssist_Bundesliga_List = []
for i in range(1,51):
    Bundesliga_assists = Fox_GoalScoredPlusAssist_Bundesliga[i].contents[11].text
    Fox_GoalScoredPlusAssist_Bundesliga_List.append(Bundesliga_assists)
    
print(Fox_GoalScoredPlusAssist_Bundesliga_List)
# Out:
# ['6', '0', '1', '11', '3', '2', '0', '0', '1', '2', '1', '0', '1', '2', '0', '0', '3', '1', '0', '1', '4', '0', '0', '2', '6', '1', '2', '1', '0', '0', '0', '1', '1', '1', '1', '3', '2', '0', '1', '0', '0', '0', '0', '1', '1', '5', '0', '0', '2', '0']

# %%
Fox_Club_goal_name = Fox_goal_page_soup.findAll('span',{"class":"wisbb_tableAbbrevLink"})
Fox_Club_goal_name[0].text[1:4]
# Out:
# 'DOR'

# %%
Fox_Club_goal_name_list = []
for i in range(50):
    get_name = Fox_Club_goal_name[i].text[1:4]
    Fox_Club_goal_name_list.append(get_name)


print(Fox_Club_goal_name_list)
# Out:
# ['DOR', 'FBG', 'FBG', 'LEV', 'MUN', 'SKE', 'SKE', 'HAN', 'AUG', 'FCN', 'FCN', 'DUS', 'HAN', 'BM\n', 'BM\n', 'BM\n', 'HAN', 'AUG', 'AUG', 'AUG', 'AUG', 'RBL', 'RBL', 'RBL', 'HB\n', 'BRE', 'LEV', 'MUN', 'MUN', 'SKE', 'SGT', 'WOL', 'SKE', 'HAN', 'BRE', 'BRE', 'BRE', 'HB\n', 'DOR', 'AUG', 'BM\n', 'BM\n', 'HAN', 'HAN', 'HAN', 'MAI', 'MAI', 'MAI', 'FCN', 'FCN']

# %%
Fox_goal_PID = []
for i in range(50):
    c = Fox_goal_name[i][0:4]+Fox_Club_goal_name_list[i]
    Fox_goal_PID.append(c)


    
print(Fox_goal_PID)
# Out:
# ['MariDOR', 'LucaFBG', 'FlorFBG', 'JuliLEV', 'FranMUN', 'DaniSKE', 'BreeSKE', 'NicoHAN', 'Ji DAUG', 'MikaFCN', 'HannFCN', 'KaanDUS', 'HendHAN', 'PatrBM\n', 'LarsBM\n', 'DeniBM\n', 'IhlaHAN', 'MichAUG', 'MartAUG', 'RaniAUG', 'JonaAUG', 'JeanRBL', 'LukaRBL', 'MarcRBL', 'DaviHB\n', 'JohaBRE', 'LucaLEV', 'KingMUN', 'ArjeMUN', 'NabiSKE', 'AnasSGT', 'RenaWOL', 'StevSKE', 'BobbHAN', 'YuyaBRE', 'DavyBRE', 'ClauBRE', 'MarkHB\n', 'AxelDOR', 'SergAUG', 'NicoBM\n', 'ChriBM\n', 'FeliHAN', 'NiclHAN', 'JonaHAN', 'DaniMAI', 'JeanMAI', 'AnthMAI', 'EduaFCN', 'GeorFCN']

# %%
Fox_Goal_data = list(zip(Fox_goal_name,Fox_Club_goal_name_list,Fox_GoalScored_Bundesliga,Fox_goal_PID))
Fox_Goal_data_df = pd.DataFrame(data = Fox_Goal_data,columns = ['Player Name','Club','Goals','PlayerID'])
Fox_Goal_data_df.head(10)
Fox_Goal_data_df_copy = Fox_Goal_data_df
Fox_Goal_data_df_copy.head()
# Out:
#              Player Name Club Goals PlayerID
# 0            Mario Gotze  DOR     4  MariDOR
# 1            Lucas Holer  FBG     4  LucaFBG
# 2  Florian Niederlechner  FBG     4  FlorFBG
# 3          Julian Brandt  LEV     4  JuliLEV
# 4          Franck Ribery  MUN     4  FranMUN

# %%
Bundesliga_assist_df.head(10)
Bundesliga_assist_df_copy = Bundesliga_assist_df
Bundesliga_assist_df_copy.head()
# Out:
#            Player Name Club Assists PlayerID Goals
# 0        Marco Richter  AUG       3  MarcAUG     0
# 1         Serge Gnabry  MUN       3  SergMUN     7
# 2          Nico Schulz  HOF       3  NicoHOF     1
# 3  Ludwig Augustinsson  BRE       3  LudwBRE     1
# 4    Christian Pulisic  DOR       3  ChriDOR     2

# %%
minutes_played_goal_fox_Bundesliga = Fox_goal_page_soup.findAll('tr',{"class":"wisbb_fvStand"})
print(minutes_played_goal_fox_Bundesliga[1].contents[7].text)
# Out:
# 1127

# %%
minutes_played_goal_fox_Bundesliga_list = []
for i in range(1,51):
    get_min_played = minutes_played_goal_fox_Bundesliga[i].contents[7].text
    minutes_played_goal_fox_Bundesliga_list.append(get_min_played)
    
print(minutes_played_goal_fox_Bundesliga_list)
# Out:
# ['1127', '670', '301', '1463', '655', '1434', '545', '207', '719', '775', '1302', '1222', '1057', '425', '1371', '979', '270', '1243', '855', '1609', '1440', '85', '1480', '1442', '1331', '864', '336', '767', '83', '1188', '451', '677', '621', '900', '386', '1595', '357', '1137', '1620', '466', '1558', '366', '520', '433', '514', '1499', '1565', '361', '633', '1123']

# %%
Fox_Goal_data_df['Minutes Played'] = minutes_played_goal_fox_Bundesliga_list
Fox_Goal_data_df.head()
# Out:
#              Player Name Club Goals PlayerID Minutes Played
# 0            Mario Gotze  DOR     4  MariDOR           1127
# 1            Lucas Holer  FBG     4  LucaFBG            670
# 2  Florian Niederlechner  FBG     4  FlorFBG            301
# 3          Julian Brandt  LEV     4  JuliLEV           1463
# 4          Franck Ribery  MUN     4  FranMUN            655

# %%
print(minutes_played_goal_fox_Bundesliga[1].contents[15].text)
# Out:
# 18

# %%
total_shots_fox_Bundesliga_list = []
for i in range(1,51):
    get_shots = minutes_played_goal_fox_Bundesliga[i].contents[15].text
    total_shots_fox_Bundesliga_list.append(get_shots)
    
print(total_shots_fox_Bundesliga_list)
# Out:
# ['18', '18', '26', '48', '19', '37', '16', '15', '21', '22', '29', '18', '40', '13', '33', '29', '22', '65', '20', '11', '15', '13', '8', '56', '38', '27', '24', '20', '17', '20', '18', '22', '17', '16', '19', '26', '20', '30', '31', '12', '9', '4', '9', '36', '10', '16', '26', '21', '20', '13']

# %%
total_shots_target_fox_Bundesliga_list = []
for i in range(1,51):
    get_shots_target = minutes_played_goal_fox_Bundesliga[i].contents[13].text
    total_shots_target_fox_Bundesliga_list.append(get_shots_target)

    
print(total_shots_target_fox_Bundesliga_list)
# Out:
# ['12', '8', '16', '19', '9', '9', '11', '8', '7', '9', '8', '9', '13', '3', '13', '11', '10', '21', '5', '4', '8', '8', '4', '15', '17', '8', '9', '12', '8', '7', '7', '5', '7', '9', '5', '8', '5', '17', '11', '4', '3', '2', '2', '14', '5', '6', '7', '8', '9', '4']

# %%
Fox_Goal_data_df['SOG'] = total_shots_target_fox_Bundesliga_list

# %%
Fox_Goal_data_df['Shots'] = total_shots_fox_Bundesliga_list

# %%
Fox_Goal_data_df['Assists'] = Fox_GoalScoredPlusAssist_Bundesliga_List

# %%
Fox_Goal_data_df.head()
# Out:
#              Player Name Club Goals PlayerID Minutes Played SOG Shots Assists
# 0            Mario Gotze  DOR     4  MariDOR           1127  12    18       6
# 1            Lucas Holer  FBG     4  LucaFBG            670   8    18       0
# 2  Florian Niederlechner  FBG     4  FlorFBG            301  16    26       1
# 3          Julian Brandt  LEV     4  JuliLEV           1463  19    48      11
# 4          Franck Ribery  MUN     4  FranMUN            655   9    19       3

# %%
Minutes_played_SOG_S_Fox = Bundesliga_assists_page_soup.findAll('tr',{"class":"wisbb_fvStand"})
print(Minutes_played_SOG_S_Fox[1].contents[7].text)
# Out:
# 590

# %%
MP_Fox_Bundesliga_assists_list = []
for i in range(1,51):
    get_MP = Minutes_played_SOG_S_Fox[i].contents[7].text
    MP_Fox_Bundesliga_assists_list.append(get_MP)

print(MP_Fox_Bundesliga_assists_list)
# Out:
# ['590', '980', '1415', '1710', '276', '1707', '1248', '655', '717', '1336', '1710', '726', '866', '504', '848', '736', '1449', '1595', '1502', '140', '1301', '1362', '1619', '1283', '1710', '425', '1071', '578', '1330', '633', '680', '813', '1447', '1146', '1380', '563', '-', '1292', '1520', '1442', '1364', '863', '1080', '846', '907', '1130', '1061', '1194', '1710', '650']

# %%
SOG_Fox_Bundesliga_assists_list = []
for i in range(1,51):
    get_SOG = Minutes_played_SOG_S_Fox[i].contents[13].text
    SOG_Fox_Bundesliga_assists_list.append(get_SOG)
    
print(SOG_Fox_Bundesliga_assists_list)
# Out:
# ['15', '24', '7', '5', '6', '2', '4', '9', '17', '1', '3', '11', '10', '8', '10', '3', '33', '8', '9', '5', '13', '27', '4', '7', '6', '3', '4', '2', '6', '9', '1', '2', '8', '6', '33', '15', '12', '3', '24', '15', '17', '16', '11', '0', '2', '5', '27', '6', '10', '8']

# %%
S_Fox_Bundesliga_assists_list = []
for i in range(1,51):
    get_S = Minutes_played_SOG_S_Fox[i].contents[15].text
    S_Fox_Bundesliga_assists_list.append(get_S)
    
print(S_Fox_Bundesliga_assists_list)
# Out:
# ['37', '45', '22', '17', '16', '22', '15', '19', '33', '7', '12', '23', '25', '20', '25', '9', '66', '26', '17', '9', '51', '44', '14', '29', '23', '13', '11', '4', '30', '20', '9', '7', '16', '24', '74', '38', '37', '8', '55', '56', '43', '40', '29', '7', '6', '12', '54', '17', '23', '18']

# %%
Bundesliga_assist_df['Minutes Played'] = MP_Fox_Bundesliga_assists_list

# %%
Bundesliga_assist_df['SOG'] = SOG_Fox_Bundesliga_assists_list

# %%
Bundesliga_assist_df['Shots'] = S_Fox_Bundesliga_assists_list

# %%
Bundesliga_assist_df.head()
# Out:
#            Player Name Club Assists PlayerID Goals Minutes Played SOG Shots
# 0        Marco Richter  AUG       3  MarcAUG     0            590  15    37
# 1         Serge Gnabry  MUN       3  SergMUN     7            980  24    45
# 2          Nico Schulz  HOF       3  NicoHOF     1           1415   7    22
# 3  Ludwig Augustinsson  BRE       3  LudwBRE     1           1710   5    17
# 4    Christian Pulisic  DOR       3  ChriDOR     2            276   6    16

# %%
Fox_Goal_data_df_copy = Fox_Goal_data_df
Fox_Goal_data_df_copy.head(10)
# Out:
#              Player Name Club Goals PlayerID Minutes Played SOG Shots Assists
# 0            Mario Gotze  DOR     4  MariDOR           1127  12    18       6
# 1            Lucas Holer  FBG     4  LucaFBG            670   8    18       0
# 2  Florian Niederlechner  FBG     4  FlorFBG            301  16    26       1
# 3          Julian Brandt  LEV     4  JuliLEV           1463  19    48      11
# 4          Franck Ribery  MUN     4  FranMUN            655   9    19       3
# 5       Daniel Caligiuri  SKE     4  DaniSKE           1434   9    37       2
# 6           Breel Embolo  SKE     4  BreeSKE            545  11    16       0
# 7         Nicolai Muller  HAN     4  NicoHAN            207   8    15       0
# 8            Ji Dong Won  AUG     4  Ji DAUG            719   7    21       1
# 9           Mikael Ishak  FCN     4  MikaFCN            775   9    22       2

# %%
Bundesliga_assist_df_copy = Bundesliga_assist_df
Bundesliga_assist_df_copy.head(10)
# Out:
#            Player Name Club Assists PlayerID Goals Minutes Played SOG Shots
# 0        Marco Richter  AUG       3  MarcAUG     0            590  15    37
# 1         Serge Gnabry  MUN       3  SergMUN     7            980  24    45
# 2          Nico Schulz  HOF       3  NicoHOF     1           1415   7    22
# 3  Ludwig Augustinsson  BRE       3  LudwBRE     1           1710   5    17
# 4    Christian Pulisic  DOR       3  ChriDOR     2            276   6    16
# 5        Janik Haberer  FBG       3  JaniFBG     1           1707   2    22
# 6     Charles Aranguiz  LEV       3  CharLEV     1           1248   4    15
# 7        Franck Ribery  MUN       3  FranMUN     4            655   9    19
# 8      James Rodriguez  MUN       3  JameMUN     7            717  17    33
# 9      Bastian Oczipka  SKE       3  BastSKE     1           1336   1     7

# %%
appendStuff = Bundesliga_assist_df_copy.append(Fox_Goal_data_df_copy,ignore_index = True)
# Out:
# C:\Users\91997\Anaconda3\lib\site-packages\pandas\core\frame.py:6211: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   sort=sort)

# %%
appendStuff
# Out:
#    Assists  Club Goals Minutes Played           Player Name  PlayerID SOG  \
# 0        3   AUG     0            590         Marco Richter   MarcAUG  15
# 1        3   MUN     7            980          Serge Gnabry   SergMUN  24
# 2        3   HOF     1           1415           Nico Schulz   NicoHOF   7
# 3        3   BRE     1           1710   Ludwig Augustinsson   LudwBRE   5
# 4        3   DOR     2            276     Christian Pulisic   ChriDOR   6
# 5        3   FBG     1           1707         Janik Haberer   JaniFBG   2
# 6        3   LEV     1           1248      Charles Aranguiz   CharLEV   4
# 7        3   MUN     4            655         Franck Ribery   FranMUN   9
# 8        3   MUN     7            717       James Rodriguez   JameMUN  17
# 9        3   SKE     1           1336       Bastian Oczipka   BastSKE   1
# 10       3   DUS     1           1710   Matthias Zimmermann   MattDUS   3
# 11       3   WOL     2            726         Josip Brekalo   JosiWOL  11
# ...

# %%
appendStuff = appendStuff[['Player Name','PlayerID','Club','Goals','Assists','Minutes Played','SOG','Shots']]
appendStuff.shape
# Out:
# (100, 8)

# %%
appendStuff.to_csv('Bundesliga_data_new2.csv')
