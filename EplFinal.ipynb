# %%
import pandas as pd

# %%
df_EPL_1 = pd.read_csv("C:\\Users\\91997\\EPL_data_new1.csv")

# %%
#df.drop(['Unnamed: 0'],axis = 1,inplace = True)

# %%
df_EPL_1_copy = df_EPL_1

# %%
df_EPL_1_copy.drop_duplicates(subset = 'PlayerID',inplace = True)

# %%
df_EPL_1_copy.reset_index(drop = True,inplace=True)

# %%
df_EPL_1_copy.drop('Unnamed: 0',axis = 1,inplace = True)

# %%
print(len(df_EPL_1['Player Name'].unique()))
# Out:
# 73

# %%
df_EPL_2 = pd.read_csv("C:\\Users\\91997\\EPL_data_new2.csv")

# %%
df_EPL_2_copy = df_EPL_2

# %%
df_EPL_2_copy.drop('Unnamed: 0',axis = 1,inplace = True)

# %%
print(len(df_EPL_2_copy['Minutes Played'].unique()))
# Out:
# 86

# %%
df_EPL_2.drop_duplicates(subset = 'PlayerID',inplace = True)

# %%
df_EPL_2.shape
# Out:
# (90, 8)

# %%
df_EPL_1.shape
# Out:
# (73, 8)

# %%
EPL_onePlusTwo = df_EPL_1.append(df_EPL_2,ignore_index = True)

# %%
print(len(EPL_onePlusTwo['PlayerID'].unique()))
# Out:
# 143

# %%
EPL_onePlusTwo_copy = EPL_onePlusTwo

# %%
EPL_onePlusTwo_copy.drop_duplicates(subset = 'PlayerID',inplace = True)

# %%
EPL_onePlusTwo_copy.reset_index(drop = True,inplace = True)

# %%
EPL_onePlusTwo_copy
# Out:
#                 Player Name    PlayerID    Club  Goals  Assists  \
# 0               Eden Hazard     EdenCHE     CHE     14       12
# 1         Christian Eriksen     ChriTOT     TOT      6       11
# 2               Ryan Fraser     RyanBOU     BOU      6       10
# 3                Leroy Sane     LeroMCI     MCI      9        9
# 4                Paul Pogba     PaulMUN     MUN     11        9
# 5            Andy Robertson     AndyLIV     LIV      0        8
# 6           Raheem Sterling     RaheMCI     MCI     15        8
# 7       Alexandre Lacazette     AlexARS     ARS     13        7
# 8            Ryan Sessegnon     RyanFUL     FUL      2        7
# 9             Sergio Aguero     SergMCI     MCI     19        7
# 10           Bernardo Silva     BernMCI     MCI      6        7
# 11             Raul Jimenez     RaulWLV     WLV     12        7
# 12            Joao Moutinho     JoaoWLV     WLV      1        7
# 13          Ashley Westwood     AshlBUR     BUR      1        6
# ...

# %%
print(len(EPL_onePlusTwo_copy['Club'].unique()))
# Out:
# 20

# %%
EPL_onePlusTwo_copy.to_csv('EPLcombined.csv')
