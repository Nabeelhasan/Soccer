# %%
import pandas as pd

# %%
df_Ligue1_1 = pd.read_csv("C:\\Users\\91997\\Ligue1_data_new1.csv")

# %%
#df.drop(['Unnamed: 0'],axis = 1,inplace = True)

# %%
df_Ligue1_1_copy = df_Ligue1_1

# %%
df_Ligue1_1_copy.drop_duplicates(subset = 'PlayerID',inplace = True)

# %%
df_Ligue1_1_copy.reset_index(drop = True,inplace=True)

# %%
df_Ligue1_1_copy.drop('Unnamed: 0',axis = 1,inplace = True)

# %%
print(len(df_Ligue1_1['Player Name'].unique()))
# Out:
# 79

# %%
df_Ligue1_2 = pd.read_csv("C:\\Users\\91997\\Ligue1_data_new2.csv")

# %%
df_Ligue1_2_copy = df_Ligue1_2

# %%
df_Ligue1_2_copy.drop('Unnamed: 0',axis = 1,inplace = True)

# %%
print(len(df_Ligue1_2_copy['Minutes Played'].unique()))
# Out:
# 90

# %%
df_Ligue1_2.drop_duplicates(subset = 'PlayerID',inplace = True)

# %%
df_Ligue1_2.shape
# Out:
# (93, 8)

# %%
df_Ligue1_1.shape
# Out:
# (79, 8)

# %%
Ligue1_onLigue1usTwo = df_Ligue1_1.append(df_Ligue1_2,ignore_index = True)

# %%
print(len(Ligue1_onLigue1usTwo['PlayerID'].unique()))
# Out:
# 152

# %%
Ligue1_onLigue1usTwo_copy = Ligue1_onLigue1usTwo

# %%
Ligue1_onLigue1usTwo_copy.drop_duplicates(subset = 'PlayerID',inplace = True)

# %%
Ligue1_onLigue1usTwo_copy.reset_index(drop = True,inplace = True)

# %%
Ligue1_onLigue1usTwo_copy
# Out:
#              Player Name PlayerID Club  Goals  Assists Minutes Played  SOG  \
# 0             Kenny Lala  KennSTR  STR      4        9           1530    7
# 1         Angel Di Maria  AngePSG  PSG      9        9           1167   26
# 2           Nicolas Pepe  NicoLIL  LIL     18        9           1795   48
# 3          Memphis Depay  MempLYO  LYO      6        8           1412   37
# 4       Adrien Thomasson  AdriSTR  STR      5        8           1384   13
# 5          Teji Savanier  TejiNIM  NIM      4        8           1696   17
# 6            Andy Delort  AndyMTP  MTP     11        7           1576   25
# 7           Flavien Tait  FlavANG  ANG      4        6           1581   29
# 8          Lucas Ocampos  LucaMAR  MAR      3        6           1562   17
# 9        Florian Thauvin  FlorMAR  MAR     13        6           1534   33
# 10        Julian Draxler  JuliPSG  PSG      3        6           1124   15
# ...

# %%
print(len(Ligue1_onLigue1usTwo_copy['Club'].unique()))
# Out:
# 20

# %%
Ligue1_onLigue1usTwo_copy.to_csv('Ligue1combined.csv')
