# %%
import pandas as pd

# %%
df_Bundesliga_1 = pd.read_csv("C:\\Users\\91997\\Bundesliga_data_new1.csv")

# %%
#df.drop(['Unnamed: 0'],axis = 1,inplace = True)

# %%
df_Bundesliga_1_copy = df_Bundesliga_1

# %%
df_Bundesliga_1_copy.drop_duplicates(subset = 'PlayerID',inplace = True)

# %%
df_Bundesliga_1_copy.reset_index(drop = True,inplace=True)

# %%
df_Bundesliga_1_copy.drop('Unnamed: 0',axis = 1,inplace = True)

# %%
print(len(df_Bundesliga_1['Player Name'].unique()))
# Out:
# 77

# %%
df_Bundesliga_2 = pd.read_csv("C:\\Users\\91997\\Bundesliga_data_new2.csv")

# %%
df_Bundesliga_2_copy = df_Bundesliga_2

# %%
df_Bundesliga_2_copy.drop('Unnamed: 0',axis = 1,inplace = True)

# %%
print(len(df_Bundesliga_2_copy['Minutes Played'].unique()))
# Out:
# 92

# %%
df_Bundesliga_2.drop_duplicates(subset = 'PlayerID',inplace = True)

# %%
df_Bundesliga_2.shape
# Out:
# (94, 8)

# %%
df_Bundesliga_1.shape
# Out:
# (77, 8)

# %%
Bundesliga_onBundesligausTwo = df_Bundesliga_1.append(df_Bundesliga_2,ignore_index = True)

# %%
print(len(Bundesliga_onBundesligausTwo['PlayerID'].unique()))
# Out:
# 149

# %%
Bundesliga_onBundesligausTwo_copy = Bundesliga_onBundesligausTwo

# %%
Bundesliga_onBundesligausTwo_copy.drop_duplicates(subset = 'PlayerID',inplace = True)

# %%
Bundesliga_onBundesligausTwo_copy.reset_index(drop = True,inplace = True)

# %%
Bundesliga_onBundesligausTwo_copy
# Out:
#              Player Name    PlayerID    Club  Goals  Assists Minutes Played  \
# 0           Jadon Sancho     JadoDOR     DOR      8       13           1590
# 1          Julian Brandt     JuliLEV     LEV      4       11           1463
# 2         Thorgan Hazard  ThorBM\r\n  BM\r\n      9       10           1549
# 3         Joshua Kimmich     JoshMUN     MUN      2       10           1710
# 4       Sebastian Haller  SebaEF\r\n  EF\r\n     14        9           1486
# 5              Max Kruse     Max BRE     BRE     10        8           1707
# 6          Thomas Muller     ThomMUN     MUN      6        8           1330
# 7           Filip Kostic  FiliEF\r\n  EF\r\n      5        8           1701
# 8     Robert Lewandowski     RobeMUN     MUN     19        7           1710
# 9        Florian Neuhaus  FlorBM\r\n  BM\r\n      2        7           1091
# 10    Marcel Halstenberg     MarcRBL     RBL      1        6           1600
# ...

# %%
print(len(Bundesliga_onBundesligausTwo_copy['Club'].unique()))
# Out:
# 18

# %%
Bundesliga_onBundesligausTwo_copy.to_csv('Bundesligacombined.csv')
