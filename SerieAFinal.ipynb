# %%
import pandas as pd

# %%
df_SerieA_1 = pd.read_csv("C:\\Users\\91997\\SerieA_data_new1.csv")

# %%
#df.drop(['Unnamed: 0'],axis = 1,inplace = True)

# %%
df_SerieA_1_copy = df_SerieA_1

# %%
df_SerieA_1_copy.drop_duplicates(subset = 'PlayerID',inplace = True)

# %%
df_SerieA_1_copy.reset_index(drop = True,inplace=True)

# %%
df_SerieA_1_copy.drop('Unnamed: 0',axis = 1,inplace = True)

# %%
print(len(df_SerieA_1['Player Name'].unique()))
# Out:
# 81

# %%
df_SerieA_2 = pd.read_csv("C:\\Users\\91997\\SerieA_data_new2.csv")

# %%
df_SerieA_2_copy = df_SerieA_2

# %%
df_SerieA_2_copy.drop('Unnamed: 0',axis = 1,inplace = True)

# %%
print(len(df_SerieA_2_copy['Minutes Played'].unique()))
# Out:
# 88

# %%
df_SerieA_2.drop_duplicates(subset = 'PlayerID',inplace = True)

# %%
df_SerieA_2.shape
# Out:
# (89, 8)

# %%
df_SerieA_1.shape
# Out:
# (81, 8)

# %%
SerieA_onePlusTwo = df_SerieA_1.append(df_SerieA_2,ignore_index = True)

# %%
print(len(SerieA_onePlusTwo['PlayerID'].unique()))
# Out:
# 148

# %%
SerieA_onePlusTwo_copy = SerieA_onePlusTwo

# %%
SerieA_onePlusTwo_copy.drop_duplicates(subset = 'PlayerID',inplace = True)

# %%
SerieA_onePlusTwo_copy.reset_index(drop = True,inplace = True)

# %%
SerieA_onePlusTwo_copy
# Out:
#               Player Name PlayerID Club  Goals  Assists Minutes Played  SOG  \
# 0              Papu Gomez  PapuATA  ATA      6       10           1592   29
# 1           Jose Callejon  JoseNAP  NAP      3        9           1525   11
# 2                    Suso  SusoMIL  MIL      5        8           1653   31
# 3           Dries Mertens  DrieNAP  NAP     10        8           1213   25
# 4          Manuel Lazzari  ManuSPL  SPL      0        7           1409    7
# 5      Fabio Quagliarella  FabiSMP  SMP     21        7           1764   46
# 6       Cristiano Ronaldo  CrisJUV  JUV     19        7           1429   60
# 7            Josip Ilicic  JosiATA  ATA      9        6           1371   24
# 8       Cristiano Biraghi  CrisFIO  FIO      1        6           1800    6
# 9         Mario Mandzukic  MariJUV  JUV      8        6           1292   16
# 10       Hakan Calhanoglu  HakaMIL  MIL      1        6           1669   18
# ...

# %%
print(len(SerieA_onePlusTwo_copy['Club'].unique()))
# Out:
# 20

# %%
SerieA_onePlusTwo_copy['Club Name'] =

# %%
SerieA_onePlusTwo_copy.to_csv('SerieAcombined.csv')
