# %%
import pandas as pd

# %%
df_Laliga_1 = pd.read_csv("C:\\Users\\91997\\Laliga_data_new1.csv")

# %%
#df.drop(['Unnamed: 0'],axis = 1,inplace = True)

# %%
df_Laliga_1_copy = df_Laliga_1

# %%
df_Laliga_1_copy.drop_duplicates(subset = 'PlayerID',inplace = True)

# %%
df_Laliga_1_copy.reset_index(drop = True,inplace=True)

# %%
df_Laliga_1_copy.drop('Unnamed: 0',axis = 1,inplace = True)

# %%
print(len(df_Laliga_1['Player Name'].unique()))
# Out:
# 79

# %%
df_Laliga_2 = pd.read_csv("C:\\Users\\91997\\Laliga_data_new2.csv")

# %%
df_Laliga_2_copy = df_Laliga_2

# %%
df_Laliga_2_copy.drop('Unnamed: 0',axis = 1,inplace = True)

# %%
print(len(df_Laliga_2_copy['Minutes Played'].unique()))
# Out:
# 90

# %%
df_Laliga_2.drop_duplicates(subset = 'PlayerID',inplace = True)

# %%
df_Laliga_2.shape
# Out:
# (92, 8)

# %%
df_Laliga_1.shape
# Out:
# (79, 8)

# %%
Laliga_onLaligausTwo = df_Laliga_1.append(df_Laliga_2,ignore_index = True)

# %%
print(len(Laliga_onLaligausTwo['PlayerID'].unique()))
# Out:
# 153

# %%
Laliga_onLaligausTwo_copy = Laliga_onLaligausTwo

# %%
Laliga_onLaligausTwo_copy.drop_duplicates(subset = 'PlayerID',inplace = True)

# %%
Laliga_onLaligausTwo_copy.reset_index(drop = True,inplace = True)

# %%
Laliga_onLaligausTwo_copy
# Out:
#             Player Name    PlayerID    Club  Goals  Assists Minutes Played  \
# 0          Lionel Messi     LionBAR     BAR     32       12           1585
# 1                  Jony     JonyALA     ALA      4       10           1492
# 2         Pablo Sarabia     PablSEV     SEV      9        9           1337
# 3            Jordi Alba     JordBAR     BAR      1        8           1755
# 4          Brais Mendez     BraiCEL     CEL      6        7           1792
# 5         Santi Cazorla     SantVIL     VIL      4        7           1577
# 6     Antoine Griezmann     AntoATL     ATL     13        7           1832
# 7         Sergi Roberto     SergBAR     BAR      0        6           1201
# 8           Luis Suarez     LuisBAR     BAR     19        6           1729
# 9            Jaime Mata     JaimGET     GET     13        6           1500
# 10    Wissam Ben Yedder     WissSEV     SEV     16        6           1579
# ...

# %%
print(len(Laliga_onLaligausTwo_copy['Club'].unique()))
# Out:
# 21

# %%
Laliga_onLaligausTwo_copy.to_csv('Laligacombined.csv')
